# %%
import gym
import numpy as np
import pandas as pd
import random
import tensorflow as tf
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.api import VAR, DynamicVAR
# %matplotlib inline
# Out:
# C:\Users\Laurens\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
mdata = pd.read_csv('data.csv') #Three stocks (R,X_s,X_b) Without predictors

# %%
## VAR
dates = mdata['Date']
data = mdata[['r','xs','xb']]
data.index = pd.DatetimeIndex(dates)
model = VAR(data[['r','xs','xb']])

results = model.fit(1)
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 27, Jul, 2017
# Time:                     16:28:06
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -26.4113
# Nobs:                     754.000    HQIC:                  -26.4566
# Log likelihood:           6787.17    FPE:                3.14592e-12
# AIC:                     -26.4849    Det(Omega_mle):     3.09638e-12
# --------------------------------------------------------------------
# Results for equation r
# ========================================================================
#            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------
# const         0.000447         0.000109            4.094           0.000
# L1.r          0.459291         0.032450           14.154           0.000
# L1.xs        -0.004786         0.002438           -1.963           0.050
# L1.xb         0.009811         0.007228            1.357           0.175
# ========================================================================
#
# Results for equation xs
# ========================================================================
#            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------
# const         0.004663         0.001621            2.876           0.004
# L1.r          0.096658         0.481918            0.201           0.841
# L1.xs         0.074194         0.036206            2.049           0.041
# L1.xb         0.363500         0.107337            3.387           0.001
# ========================================================================
#
# Results for equation xb
# ========================================================================
#            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------
# const         0.001163         0.000540            2.152           0.032
# L1.r          0.450992         0.160597            2.808           0.005
# L1.xs        -0.061160         0.012065           -5.069           0.000
# L1.xb         0.113145         0.035770            3.163           0.002
# ========================================================================
#
# Correlation matrix of residuals
#              r        xs        xb
# r     1.000000  0.026843  0.040065
# xs    0.026843  1.000000  0.068834
# xb    0.040065  0.068834  1.000000

# %%
data.plot(x='Date', y='r')
data.plot(x='Date', y='xs')
data.plot(x='Date', y='xb')
